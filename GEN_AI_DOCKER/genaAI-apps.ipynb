# %%
# %pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      1.4.0
# accelerate                   0.20.3
# aenum                        3.1.15
# aiofiles                     23.2.1
# aiohttp                      3.8.4
# aiosignal                    1.3.1
# aiosqlite                    0.19.0
# anyio                        3.6.2
# appdirs                      1.4.4
# APScheduler                  3.10.4
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# argparse-addons              0.12.0
# arrow                        1.2.3
# asammdf                      4.0.2
# asgiref                      3.7.2
# astor                        0.8.1
# astunparse                   1.6.3
# async-timeout                4.0.2
# asynctest                    0.13.0
# atomicwrites                 1.4.1
# attrs                        22.2.0
# azure-core                   1.30.0
# azure-storage-blob           12.19.0
# ...
